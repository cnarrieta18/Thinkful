# %% [markdown]
# # Assignments
# When you've given it a try, you can find a sample solution [here.](https://github.com/Thinkful-Ed/data-201-resources/blob/master/solutions/Prep%20course/3.3.4.ipynb)
#
# [Distributions.](https://www.causascientia.org/math_stat/Dists/Compendium.pdf)
#
# To complete the following drills, you'll need to use your Python skills to create some datasets, then use your new statistical knowledge to summarize them. Choose 6 distributions from the list of random distributions available in NumPy, called [“Distributions”](https://docs.scipy.org/doc/numpy/reference/random/legacy.html)
#
# For each distribution:
#
# 1. Generate a random variable with 100 datapoints using the code
#     `distributionvar = np.random.distributionname([arguments], 100)`
#     replacing `distributionvar` with an appropriate variable name and `distributionname` with the name of the distribution you’ve chosen, and filling in the empty space in the parentheses with your chosen values for the appropriate parameters. If you feel uncertain about how to do this, go back to the “Other Distributions” assignment for examples of code to use as a starting point.
# 2. Graph the variable using a histogram.
# 3. Compute the mean and standard deviation and plot them as vertical lines on the histogram.
# 4. Evaluate whether the descriptive statistics provided useful information about the variable. Can you identify any common characteristics of the distributions that could be usefully described using the mean and/or standard deviation, versus the ones that could not?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def summary_stat_plot(array):
    
    #Plot a histogram for rand1.
    plt.hist(array, bins=20, color='c')

    # Add a vertical line at the mean.
    plt.axvline(array.mean(), 
                color='b', 
                linestyle='solid', 
                linewidth=2, 
                label=f'mean: {round(array.mean(),2)}')

    # Add a vertical line at one standard deviation above the mean.
    plt.axvline(array.mean() + array.std(), 
                color='b', 
                linestyle='dashed', 
                linewidth=2, 
                label=f'±std: {round(array.std(),2)}')

    # Add a vertical line at one standard deviation below the mean.
    plt.axvline(array.mean() - array.std(), color='b', linestyle='dashed', linewidth=2)
    
    # Add legend with mean and std
    plt.legend(shadow=True,loc=0)
    
    return plt.show();

# %%
uniform = np.random.uniform(0,10, 100)
summary_stat_plot(uniform)

# %%
normal = np.random.normal(5, 2.5, 100)
summary_stat_plot(normal)

# %%
poisson = np.random.poisson(2, 100)
summary_stat_plot(poisson)

# %%
bernoulli = np.random.binomial(1,0.5, 100)
summary_stat_plot(bernoulli)

# %%
binomial = np.random.binomial(10,0.5, 100)
summary_stat_plot(binomial)

# %%
gamma = np.random.gamma(5,1, 100)
summary_stat_plot(gamma)

# %%
logistic = np.random.logistic(0, 1, 100)
summary_stat_plot(logistic)

# %%
exponential = np.random.exponential(1, 100)
summary_stat_plot(exponential)

# %% [markdown]
# Additionally:
#
# 1. Generate two normally-distributed variables, one with a mean of 5 and standard deviation of 0.5, and the other with a mean of 10 and standard deviation of 1.
# 2. Add them together to create a third variable.
# 3. Graph the third variable using a histogram.
# 4. Compute the mean and standard deviation and plot them as vertical lines on the histogram.
# 5. Evaluate the descriptive statistics against the data.

# %%
normal1 = np.random.normal(5, 0.5, 100)
normal2 = np.random.normal(10, 1, 100)

# perform addition 
normal_add = normal1 + normal2

# mix to create larger array
normal_combine = np.concatenate((normal1, normal2), axis=None)

summary_stat_plot(normal_add)
summary_stat_plot(normal_combine)

# %% [markdown]
# Not sure what "add them together" meant exactly, so I made an addition set and combination set.
#
# The **addition set** has:
# - `normal_add.mean() = normal1_mean() + normal2.mean()`
# - `normal_add.std() = sqrt(normal1_var() + normal2.var())`
#
# The **combination set** has:
# - `normal_combine.mean() = (normal1_mean() + normal2.mean()).mean()`
# - standard deviation that locate the individual means of the original distributions.
