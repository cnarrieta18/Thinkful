# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns

# %matplotlib inline

# %%
# data output display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)
pd.set_option('display.precision', 3)

# %% [markdown]
# # Dataset

# %%
federal_rates = pd.read_csv('federal.csv')
mortgage_rates = pd.read_csv('mortgage.csv')

# %% [markdown]
# # Merging the data

# %%
federal_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 904 entries, 0 to 903
# Data columns (total 4 columns):
# DATE            904 non-null object
# INTEREST        752 non-null float64
# UNEMPLOYMENT    752 non-null float64
# INFLATION       710 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 28.3+ KB

# %%
mortgage_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549 entries, 0 to 548
# Data columns (total 2 columns):
# DATE        549 non-null object
# MORTGAGE    549 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 8.7+ KB

# %%
rates = pd.merge(federal_rates, mortgage_rates, on='DATE', how='right')
rates
# Out:
#            DATE  INTEREST  UNEMPLOYMENT  INFLATION  MORTGAGE
# 0    1971-04-01      4.15           5.9        5.0     7.310
# 1    1971-05-01      4.63           5.9        5.2     7.425
# 2    1971-06-01      4.91           5.9        4.9     7.530
# 3    1971-07-01      5.31           6.0        4.9     7.604
# 4    1971-08-01      5.56           6.1        4.6     7.698
# 5    1971-09-01      5.55           6.0        4.4     7.688
# 6    1971-10-01      5.20           5.8        3.8     7.628
# 7    1971-11-01      4.91           6.0        3.3     7.550
# 8    1971-12-01      4.14           6.0        3.1     7.480
# 9    1972-01-01      3.50           5.8        3.1     7.438
# ..          ...       ...           ...        ...       ...
# 539  2016-03-01      0.36           5.0        2.2     3.694
# 540  2016-04-01      0.37           5.0        2.1     3.605
# 541  2016-05-01      0.37           4.7        2.2     3.600
# 542  2016-06-01      0.38           4.9        2.2     3.568
# 543  2016-07-01      0.39           4.9        2.2     3.440
# 544  2016-08-01      0.40           4.9        2.3     3.435
# 545  2016-09-01      0.40           4.9        2.2     3.460
# 546  2016-10-01      0.40           4.8        2.1     3.470
# 547  2016-11-01      0.41           4.6        2.1     3.770
# 548  2016-12-01      0.54           4.7        2.2     4.198
#
# [549 rows x 5 columns]

# %%
#check for data types and null values
rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 549 entries, 0 to 548
# Data columns (total 5 columns):
# DATE            549 non-null object
# INTEREST        549 non-null float64
# UNEMPLOYMENT    549 non-null float64
# INFLATION       549 non-null float64
# MORTGAGE        549 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 25.7+ KB

# %%
rates['DATE'] = pd.to_datetime(rates['DATE'])

# %%
rates.to_csv('rates.csv', index=False)

# %% [markdown]
# # Scatterplot

# %%
## matplotlib plot
# # matplotlib date format modules
# from matplotlib.dates import DateFormatter
# import matplotlib.dates as mdates

# # define the date format
# myFmt = mdates.DateFormatter('%Y')

# # plot the data
# fig, ax = plt.subplots(figsize=(20,8))
# ax.plot(rates['DATE'], rates['INFLATION'], label='inflation', linewidth=5)
# ax.plot(rates['DATE'], rates['UNEMPLOYMENT'], label='unemployment', linewidth=1)
# ax.plot(rates['DATE'], rates['INTEREST'], label='interest', linewidth=3)
# ax.plot(rates['DATE'], rates['MORTGAGE'], label='mortgage', linewidth=7)

# ax.set(ylabel='rates', xlabel='timeline', title='Economic Indicators {}-{}'.format(rates['DATE'].dt.year.min(),rates['DATE'].dt.year.max()))
# # ax.set_title('US Metrics from {} to {}'.format(inflation_rates['DATE'].min().strftime('%Y'), inflation_rates['DATE'].max().strftime('%Y')))
# ax.legend()

# # inform axis that it is plotting dates
# ax.xaxis_date() 

# # use format specified as myFmt
# ax.xaxis.set_major_formatter(myFmt);

# # locate dates of financial crisis
# financial_crisis = pd.to_datetime([1973, 1975, 1980, 1982, 1989, 2001, 2007, 2009], format='%Y')
# for year in financial_crisis:
#     ax.axvline(x = year)
    
# plt.savefig('timeseries_rates.png')

# %%
## seaborn plot
# rates = rates.set_index('DATE')
# %matplotlib notebook
# plt.figure(figsize=(20,10))
# sns.lineplot(data=rates);
# sns.tsplot(rates, time='DATE', value='INTEREST');

# %%
rates = rates.set_index('DATE')
rates.index
# Out:
# DatetimeIndex(['1971-04-01', '1971-05-01', '1971-06-01', '1971-07-01',
#                '1971-08-01', '1971-09-01', '1971-10-01', '1971-11-01',
#                '1971-12-01', '1972-01-01',
#                ...
#                '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01',
#                '2016-07-01', '2016-08-01', '2016-09-01', '2016-10-01',
#                '2016-11-01', '2016-12-01'],
#               dtype='datetime64[ns]', name='DATE', length=549, freq=None)

# %%
## plotly plot

import plotly
plotly.offline.init_notebook_mode(connected=True)
inflation = {'type': 'scatter', 'x': rates.index.tolist(), 'y': rates['INFLATION'].tolist(), 'name':'inflation'}
unemployment = {'type': 'scatter', 'x': rates.index.tolist(), 'y': rates['UNEMPLOYMENT'].tolist(), 'name':'unemployment'}
interest = {'type': 'scatter', 'x': rates.index.tolist(), 'y': rates['INTEREST'].tolist(), 'name':'interest'}
mortgage = {'type': 'scatter', 'x': rates.index.tolist(), 'y': rates['MORTGAGE'].tolist(), 'name':'mortgage'}
#trace = dict(type=‘bar’, x=[], y=[], text=[], mode=‘marker’)

plotly.offline.iplot([inflation, unemployment, interest, mortgage])
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="93d14682-c923-4b89-b95e-474b5275eba4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("93d14682-c923-4b89-b95e-474b5275eba4")) {
#                     Plotly.newPlot(
#                         '93d14682-c923-4b89-b95e-474b5275eba4',
#                         [{"name": "inflation", "type": "scatter", "x": ["1971-04-01T00:00:00", "1971-05-01T00:00:00", "1971-06-01T00:00:00", "1971-07-01T00:00:00", "1971-08-01T00:00:00", "1971-09-01T00:00:00", "1971-10-01T00:00:00", "1971-11-01T00:00:00", "1971-12-01T00:00:00", "1972-01-01T00:00:00", "1972-02-01T00:00:00", "1972-03-01T00:00:00", "1972-04-01T00:00:00", "1972-05-01T00:00:00", "1972-06-01T00:00:00", "1972-07-01T00:00:00", "1972-08-01T00:00:00", "1972-09-01T00:00:00", "1972-10-01T00:00:00", "1972-11-01T00:00:00", "1972-12-01T00:00:00", "1973-01-01T00:00:00", "1973-02-01T00:00:00", "1973-03-01T00:00:00", "1973-04-01T00:00:00", "1973-05-01T00:00:00", "1973-06-01T00:00:00", "1973-07-01T00:00:00", "1973-08-01T00:00:00", "1
-01T00:00:00", "1982-08-01T00:00:00", "1982-09-01T00:00:00", "1982-10-01T00:00:00", "1982-11-01T00:00:00", "1982-12-01T00:00:00", "1983-01-01T00:00:00", "1983-02-01T00:00:00", "1983-03-01T00:00:00", "1983-04-01T00:00:00", "1983-05-01T00:00:00", "1983-06-01T00:00:00", "1983-07-01T00:00:00", "1983-08-01T00:00:00", "1983-09-01T00:00:00", "1983-10-01T00:00:00", "1983-11-01T00:00:00", "1983-12-01T00:00:00", "1984-01-01T00:00:00", "1984-02-01T00:00:00", "1984-03-01T00:00:00", "1984-04-01T00:00:00", "1984-05-01T00:00:00", "1984-06-01T00:00:00", "1984-07-01T00:00:00", "1984-08-01T00:00:00", "1984-09-01T00:00:00", "1984-10-01T00:00:00", "1984-11-01T00:00:00", "1984-12-01T00:00:00", "1985-01-01T00:00:00", "1985-02-01T00:00:00", "1985-03-01T00:00:00", "1985-04-01T00:00:00", "1985-05-01T00:00:00", "1985-06-01T00:00: ...

# %% [markdown]
# This scatterplot represents the different inflation rates in the US over time, between 1954 and 2017.  It shows a downward trend for the majority of the timeline, with the maximum rate peaking close to 14%.  There are a few "mini" peaks, and we need to check if dates correspond to financial crisis in the US (ie. early and mid 1980's, 1990, 2000, and 2007).
#
# Observations:
#
# - unemployment spikes follow financial crisis, with peak around 10%
# - dropping interest rates is a response to financial crisis
# -

# %% [markdown]
# # Plotting Functions

# %%
def summary_stat_plot(plt, array, num_bins=20):
    
    # Plot a histogram.
    sns.distplot(array)
    
    # Add a vertical line at the mean.
    plt.axvline(array.mean(), 
                color='b', 
                linestyle='solid', 
                linewidth=2, 
                label=f'mean: {round(array.mean(),2)}')

    # Add a vertical line at one standard deviation above the mean.
    plt.axvline(array.mean() + array.std(), 
                color='b', 
                linestyle='dashed', 
                linewidth=2, 
                label=f'±std: {round(array.std(),2)}')

    # Add a vertical line at one standard deviation below the mean.
    plt.axvline(array.mean() - array.std(), color='b', linestyle='dashed', linewidth=2)
    
    # Add legend with mean and std
    plt.legend(shadow=True,loc=0)
    
    plt.title('US {} RATE DISTRIBUTION'.format(array.name))
    plt.xlabel('{} RATE'.format(array.name))
    plt.ylabel('FREQEUNCY');
    
    return plt

# %%
def qq_plot(plt, series, distribution='normal'):
    
    # Making two variables.
    rand1 = np.random.normal(0, 1, len(series))
    rand2 = np.random.gamma(5,1, len(series))

    # Sorting the values in ascending order.
    unknown_dist = series.sort_values()
    unknown_dist_mean = unknown_dist.mean()
    unknown_dist_std = unknown_dist.std()
    unknown_dist_norm = (unknown_dist - unknown_dist_mean) / unknown_dist_std
    rand1.sort()
    rand2.sort()
    
    # Plotting the variable against series.    
    if distribution == 'normal':
        plt.title('QQ Plot - Normal Distribution')
        plt.plot(unknown_dist, rand1, "o")
    elif distribution == 'gamma':
        plt.title('QQ Plot - Gamma Distribution')
        plt.plot(unknown_dist, rand2, "o")
    
    return plt

# %%
def combine_plots(series):

    plt.figure(figsize = [10,5])

    # histogram
    plt.subplot(1,2,1)
    fig = summary_stat_plot(plt, series)

    # qq plot
    plt.subplot(1,2,2)
    fig2 = qq_plot(fig, series)

    fig2.savefig('Images/variable_analysis_{}.png'.format(series.name));

# %%
def box_plot(series):
    
    plt.boxplot(series)
    plt.title('US {} RATE RANGE'.format(series.name))
    plt.ylabel('RATES')
    plt.grid()
    plt.savefig('Images/boxplot_{}.png'.format(series.name));

# %% [markdown]
# # Inflation Rate

# %%
mean = rates['INFLATION'].mean()
median = rates['INFLATION'].median()
rate_min = rates['INFLATION'].min()
rate_max = rates['INFLATION'].max()

print('mean: {}\nmedian: {}\nmin: {}\nmax: {}'.format(mean, median, rate_min, rate_max))
# Out:
# mean: 4.02149362477231
# median: 3.0
# min: 0.6
# max: 13.6

# %%
combine_plots(rates['INFLATION'])

# %% [markdown]
# From this spread, it is comforting to know that +7% rates are not the most common.  It looks like a gamma distribution.

# %%
box_plot(rates['INFLATION'])

# %% [markdown]
# # Unemployment Rate

# %%
mean = rates['UNEMPLOYMENT'].mean()
median = rates['UNEMPLOYMENT'].median()
rate_min = rates['UNEMPLOYMENT'].min()
rate_max = rates['UNEMPLOYMENT'].max()

print('mean: {}\nmedian: {}\nmin: {}\nmax: {}'.format(mean, median, rate_min, rate_max))
# Out:
# mean: 6.376684881602911
# median: 6.0
# min: 3.8
# max: 10.8

# %%
combine_plots(rates['UNEMPLOYMENT'])

# %% [markdown]
# Looks like another gamma distribution.

# %%
box_plot(rates['UNEMPLOYMENT'])

# %% [markdown]
# # Interest (Effective Federal Funds) Rate

# %%
mean = rates['INTEREST'].mean()
median = rates['INTEREST'].median()
rate_min = rates['INTEREST'].min()
rate_max = rates['INTEREST'].max()

print('mean: {}\nmedian: {}\nmin: {}\nmax: {}'.format(mean, median, rate_min, rate_max))
# Out:
# mean: 5.348287795992715
# median: 5.25
# min: 0.07
# max: 19.1

# %%
combine_plots(rates['INTEREST'])

# %%
box_plot(rates['INTEREST'])

# %% [markdown]
# # 30yr Mortgage Rate

# %%
mean = rates['MORTGAGE'].mean()
median = rates['MORTGAGE'].median()
rate_min = rates['MORTGAGE'].min()
rate_max = rates['MORTGAGE'].max()

print('mean: {}\nmedian: {}\nmin: {}\nmax: {}'.format(mean, median, rate_min, rate_max))
# Out:
# mean: 8.250195810564668
# median: 7.795
# min: 3.345
# max: 18.454

# %%
combine_plots(rates['MORTGAGE'])

# %%
box_plot(rates['MORTGAGE'])

# %% [markdown]
# # Finding Correlation

# %%
sns.heatmap(rates.corr(),cmap='seismic',annot=True, vmin=-1, vmax=1)

plt.savefig('Images/heatmap.png', bbox_inches='tight');

# %%
sns.pairplot(rates)
plt.title('Pairplot of rates')
plt.savefig('Images/pairplot.png');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-527bcda2f3c8> in <module>
# ----> 1 sns.pairplot(rates)
#       2 plt.title('Pairplot of rates')
#       3 plt.savefig('Images/pairplot.png');
#
# NameError: name 'rates' is not defined
